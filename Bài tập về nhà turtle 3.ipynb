# %%
import turtle
v = turtle.Turtle()
v.pensize(2)
v.left(6)
v.right(90)
v.forward(50)
v.left(90)
v.forward(100)
v.left(90)
v.forward(100)
v.left(90)
v.forward(100)
v.left(90)
v.forward(50)
v.left(18)
v.right(90)
v.forward(50)
v.left(90)
v.forward(100)
v.left(90)
v.forward(100)
v.left(90)
v.forward(100)
v.left(90)
v.forward(50)
v.left(18)
v.right(90)
v.forward(50)
v.left(90)
v.forward(100)
v.left(90)
v.forward(100)
v.left(90)
v.forward(100)
v.left(90)
v.forward(50)
v.left(18)
v.right(90)
v.forward(50)
v.left(90)
v.forward(100)
v.left(90)
v.forward(100)
v.left(90)
v.forward(100)
v.left(90)
v.forward(50)
v.left(18)
v.right(90)
v.forward(50)
v.left(90)
v.forward(100)
v.left(90)
v.forward(100)
v.left(90)
v.forward(100)
v.left(90)
v.forward(50)

turtle.done()
